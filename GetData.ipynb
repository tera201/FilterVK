# %%
import requests, time, tqdm, pandas, pickle

# %%
api = 'https://api.vk.com/method/'
key = open("text.txt")
token = key.readline()

# %%
sad = requests.get(api + 'groups.search?q=грустные&count=20&v=5.85' + token).json()['response']['items']
time.sleep(0.5)
funny = requests.get(api + 'groups.search?q=веселые&count=20&v=5.85' + token).json()['response']['items']

# %%
data1={}
data0={}

# %%
for i in tqdm.tqdm_notebook(sad):
    time.sleep(0.5)
    sad_gays=requests.get(api + 'users.search?count=500&group_id=' + str(i['id'])+'&v=5.85' + token).json()['response']['items']
    data1[i['id']]= sad_gays

# %%
for i in tqdm.tqdm_notebook(funny):
    time.sleep(0.5)
    funny_gays=requests.get(api + 'users.search?count=500&group_id=' + str(i['id'])+'&v=5.85' + token).json()['response']['items']
    data0[i['id']]= funny_gays

# %%
data11 = {'first_name': [], 'last_name': [], 'id': [], 'suicide': [], 'group': []}
data00 = {'first_name': [], 'last_name': [], 'id': [], 'suicide': [], 'group': []}

# %%
for key, val in data1.items():
    for info in val:
        data11['first_name'].append(info['first_name'])
        data11['last_name'].append(info['last_name'])
        data11['id'].append(info['id'])
        data11['suicide'].append(1)
        data11['group'].append(key)

# %%
for key, val in data0.items():
    for info in val:
        data00['first_name'].append(info['first_name'])
        data00['last_name'].append(info['last_name'])
        data00['id'].append(info['id'])
        data00['suicide'].append(0)
        data00['group'].append(key)

# %%
frame1 = pandas.DataFrame(data11)
frame1
# Out:
#       first_name      last_name         id  suicide     group
# 0           Катя       Адушкина  222267609        1  71194689
# 1      Анастасия     Третьякова    2615791        1  71194689
# 2        Nikolay    Nikolaevich       4041        1  71194689
# 3      Екатерина      Левинская  151576949        1  71194689
# 4          Антон        Соломка  140296111        1  71194689
# 5      Анастасия      Виленская  314042609        1  71194689
# 6      Анастасия       Соколова  118616259        1  71194689
# 7      Александр     Москаленко       2395        1  71194689
# 8      Анастасия        Волкова  161151316        1  71194689
# 9         Максим          Франк   94699094        1  71194689
# 10           Юра       Захарчук  242497826        1  71194689
# 11         Алина       Шабанова  162556812        1  71194689
# 12          Лили       Аксёнова   94260995        1  71194689
# 13        Оксана      Совушкина   88809814        1  71194689
# ...

# %%
frame0 = pandas.DataFrame(data00)
frame0
# Out:
#      first_name           last_name         id  suicide     group
# 0       Евгений            Гриневич    5684284        0  31234561
# 1         Арина            Данилова  230302965        0  31234561
# 2     Анастасия          Третьякова    2615791        0  31234561
# 3       Nikolay         Nikolaevich       4041        0  31234561
# 4         Данил            Гаврилов  141654175        0  31234561
# 5     Екатерина            Левченко   23598183        0  31234561
# 6        Сергей             Сергеев  100403111        0  31234561
# 7          Егор            Маркелов    4322049        0  31234561
# 8     Екатерина           Левинская  151576949        0  31234561
# 9        Максим              Шкипер   74819573        0  31234561
# 10     Кристиан              Костов   39248670        0  31234561
# 11        Denis              Kostin    7361073        0  31234561
# 12        Антон             Соломка  140296111        0  31234561
# ...

# %%
with open('sad_gays.pickle', 'wb') as f:
    pickle.dump(frame1, f)

# %%
with open('funny_gays.pickle', 'wb') as f:
    pickle.dump(frame0, f)
